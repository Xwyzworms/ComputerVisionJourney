# %%
import numpy as np
import cv2 as cv

img = cv.imread("imgRepresentation.png")

# %%
b = img[220]
print(b)
# Out:
# [[255 255 255]
#  [255 255 255]
#  [255 255 255]
#  ...
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]]

# %%
print(f"Shape of Image {img.shape}")
print(f"Size of an image {img.size}")
# Out:
# Shape of Image (588, 1284, 3)
# Size of an image 2264976

# %%
import matplotlib.pyplot as plt

img_gray = cv.imread("imgRepresentation.png",cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
img_BGR = cv.imread("imgRepresentation.png",cv.IMREAD_COLOR)
plt.imshow(img_BGR)

# %%
(b,g,r) = cv.split(img_BGR)
yoman = cv.merge([r,g,b])
plt.imshow(yoman)
